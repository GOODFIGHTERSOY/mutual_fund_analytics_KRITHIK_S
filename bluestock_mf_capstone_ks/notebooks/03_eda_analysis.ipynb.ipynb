# %%
import pandas as pd

df= pd.read_csv(r"C:\Users\KRITHIK\Downloads\Mutual_Fund_Analytics\data\raw\01_fund_master.csv")

df.head()
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %% [markdown]
# # Understanding the data

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     str
#  2   scheme_name         40 non-null     str
#  3   category            40 non-null     str
#  4   sub_category        40 non-null     str
#  5   plan                40 non-null     str
#  6   launch_date         40 non-null     str
#  7   benchmark           40 non-null     str
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     str
#  13  risk_category       40 non-null     str
#  14  sebi_category_code  40 non-null     str
# dtypes: float64(2), int64(3), str(10)
# memory usage: 9.9 KB
# None

# %%
print(df.shape)
# Out:
# (40, 15)

# %% [markdown]
# # Unique fund houses

# %%
print("Number of fund houses:",df["fund_house"].nunique())
# Out:
# Number of fund houses: 10

# %% [markdown]
# # Unique categories

# %%
print("Number of categories:",df["category"].nunique())
# Out:
# Number of categories: 2

# %% [markdown]
# # Unique sub category

# %%
print("Number of sub categories:",df["sub_category"].nunique())
# Out:
# Number of sub categories: 12

# %% [markdown]
# # Unique risk category

# %%
print("Number of risk categories:",df["risk_category"].nunique())
# Out:
# Number of risk categories: 5

# %% [markdown]
# # Validating AMFI codes

# %%
df2=pd.read_csv(r"C:\Users\KRITHIK\Downloads\Mutual_Fund_Analytics\data\raw\02_nav_history.csv")
print(df2.head())
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
validation=pd.merge(df,df2,on="amfi_code",how="left")
print(validation.head())
# Out:
#    amfi_code       fund_house                                scheme_name  \
# 0     119551  SBI Mutual Fund  SBI Bluechip Fund - Regular Plan - Growth
# 1     119551  SBI Mutual Fund  SBI Bluechip Fund - Regular Plan - Growth
# 2     119551  SBI Mutual Fund  SBI Bluechip Fund - Regular Plan - Growth
# 3     119551  SBI Mutual Fund  SBI Bluechip Fund - Regular Plan - Growth
# 4     119551  SBI Mutual Fund  SBI Bluechip Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date      benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14  NIFTY 100 TRI
# 1   Equity    Large Cap  Regular  2006-02-14  NIFTY 100 TRI
# 2   Equity    Large Cap  Regular  2006-02-14  NIFTY 100 TRI
# 3   Equity    Large Cap  Regular  2006-02-14  NIFTY 100 TRI
# 4   Equity    Large Cap  Regular  2006-02-14  NIFTY 100 TRI
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# 0               1.54            1.0             500                1000
# ...

# %%
master_codes=set(df["amfi_code"])
nav_codes = set(df2["amfi_code"])
missing=master_codes-nav_codes
print("Missing Codes:", len(missing))
# Out:
# Missing Codes: 0
